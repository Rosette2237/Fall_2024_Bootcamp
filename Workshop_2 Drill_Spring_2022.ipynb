# %% [markdown]
#  # Apply What You Learned in Bootcamp!

# %% [markdown]
# Tip: refer back to the workshop if needed for similar examples and google is your best friend :)
# A lot of times, you won't know how to do something but there are a ton of online resources like the documentation of pandas methods or stackexchange posts by those who had similar questions like you.
#
# **Before starting this drill, please make a COPY of this notebook and put in your folder that you created during Bootcamp. Refer to the Workshop 1 Spring 2022 Notebook for instructions on doing this.**
#
# For each of the function headers, fill in the parts with "YOUR CODE HERE" keeping in mind the instructions provided to you in the comments. Test cases are provided to ensure that your functions work properly.

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# %ls
# Out:
#  init.ipynb         'Workshop 2 Drill Spring 2022.ipynb'
#  requirements.txt   'Workshop 2 Spring 2022.ipynb'
#  titanic_train.csv

# %%
#setup unit tests + configuration
# !pip install ipytest
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 KB 50.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 KB 30.6 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import pytest
import ipytest
ipytest.autoconfig()

# %%
df = pd.read_csv('titanic_train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q1
# I want to find a dataframe that lists just the Age, Pclass, and Sex.
#
#
# ![image.png](data:image/png;base64,...)

# %%
def get_age_class_sex(df):
  #YOUR CODE HERE
  raise NotImplementedError("Need to implement get_age_class_sex function")

# %%
# %%run_pytest
# @pytest.mark.parametrize("dataset", [
#     df,
#     df.head(5),
#     df.head(100),
#     df.head(0)
# ])
# def test_proper_columns_queried(dataset):
#   res = get_age_class_sex(dataset)
#   assert np.array_equal(list(res.columns), ["Age", "Pclass", "Sex"])
#   assert res.shape[0] == dataset.shape[0]
# Out:
# ....                                                                                         [100%]
# 4 passed in 0.07s
# %%run_pytest[clean] and %%run_pytest are deprecated in favor of %%ipytest. %%ipytest will clean tests, evaluate the cell and then run pytest. To disable cleaning, configure ipytest with ipytest.config(clean=False).

# %% [markdown]
# # Q2
#
# The df below contains the range of all ages. Suppose I want the same 3 features, but this time, I only want to see people above the age of 30. Ultimately I would like a visual of people over thirty, but let's just focus on getting a dataframe for now.
#
# ![image.png](data:image/png;base64,...)

# %%
def get_age_class_sex_over_30(df):
  #YOUR CODE HERE
  raise NotImplementedError("Need to implement get_age_class_sex_over_30")

# %%
# %%run_pytest
# @pytest.mark.parametrize("dataset", [
#     df,
#     df.head(5),
#     df.head(100),
#     df.head(0)
# ])
# def test_proper_entries_over_30(dataset):
#   res = get_age_class_sex_over_30(dataset)
#   cols = list(res.columns)
#   assert len(cols) == len(["Age", "Pclass", "Sex"])
#   assert "Age" in cols
#   assert "Pclass" in cols
#   assert "Sex" in cols
#
#   #assert res["Age"].min() > 30
#   #assert res.shape[0] <= df.shape[0]
# Out:
# %%run_pytest[clean] and %%run_pytest are deprecated in favor of %%ipytest. %%ipytest will clean tests, evaluate the cell and then run pytest. To disable cleaning, configure ipytest with ipytest.config(clean=False).
# ........                                                                                     [100%]
# 8 passed in 0.08s

# %% [markdown]
# # Q3
# I want to access the data of the 100th person, how would I do that?

# %%
def get_100th_person_info(df):
  #YOUR CODE HERE
  raise NotImplementedError("Need to implement get_100th_person_info() function")

# %%
# %%run_pytest
# @pytest.mark.parametrize("dataset", [
#     df
# ])
# def test_100th_row_info(dataset):
#   res = get_100th_person_info(dataset)
#   assert res["PassengerId"] == 100
#   assert res["Survived"] == 0
#   assert res["Pclass"] == 2
#   assert res["Name"] == "Kantor, Mr. Sinai"
#   assert res["Sex"] == "male"
#   assert res["Age"] == 34
#   assert res["SibSp"] == 1
#   assert res["Parch"] == 0
#   assert res["Ticket"] == "244367"
#   assert res["Fare"] == 26
#   assert res["Embarked"] == "S"
# Out:
# %%run_pytest[clean] and %%run_pytest are deprecated in favor of %%ipytest. %%ipytest will clean tests, evaluate the cell and then run pytest. To disable cleaning, configure ipytest with ipytest.config(clean=False).
# .........                                                                                    [100%]
# 9 passed in 0.08s

# %% [markdown]
# # Q4
# Time to go back to the main dataframe, I would like to see how many unique ages there were, what function can I use to find that?

# %%
def calc_num_unique_ages(df):
  # YOUR CODE HERE
  raise NotImplementedError("Need to implement calc_num_unique_ages()")

# %%
# %%run_pytest
# @pytest.mark.parametrize("dataset, expected", [
#     (df, 89),
#     (df.head(5), 4),
#     (df.head(0), 0),
#     (df.head(100), 46)
# ])
# def test_num_unique_ages(dataset, expected):
#   assert calc_num_unique_ages(dataset) == expected
# Out:
# ....%%run_pytest[clean] and %%run_pytest are deprecated in favor of %%ipytest. %%ipytest will clean tests, evaluate the cell and then run pytest. To disable cleaning, configure ipytest with ipytest.config(clean=False).
# .....F..F                                                                                [100%]
# ============================================= FAILURES =============================================
# ________________________________ test_num_unique_ages[dataset0-89] _________________________________
#
# dataset =      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2   ...       111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]
# expected = 89
#
#     @pytest.mark.parametrize("dataset, expected", [
#         (df, 89),
#         (df.head(5), 4),
#         (df.head(0), 0),
#         (df.head(100), 46)
#     ])
# ...

# %% [markdown]
# # Q5
# I was going through the dataframe and noticed cabin had a lot of null values, how can I see how many null values there are?
# While I'm at it, let me see how big this dataframe is as a whole.

# %%
def get_cabin_nulls_and_shape(df):
  #YOUR CODE HERE
  """
  This function should return a tuple of the form (number of null values in Cabin column, how many rows in the dataframe)
  """
  raise NotImplementedError("Need to implement get_cabin_nulls_and_shapes()")

# %%
# %%run_pytest
# @pytest.mark.parametrize("dataset, expected", [
#     (df, (687, 891)),
#     (df.head(5), (3,5)),
#     (df.head(0), (0, 0)),
# ])
# def test_cabin_nulls_shape(dataset, expected):
#   assert get_cabin_nulls_and_shape(dataset)[0] == expected[0]
#   assert get_cabin_nulls_and_shape(dataset)[1] == expected[1]
# Out:
# %%run_pytest[clean] and %%run_pytest are deprecated in favor of %%ipytest. %%ipytest will clean tests, evaluate the cell and then run pytest. To disable cleaning, configure ipytest with ipytest.config(clean=False).
# FFFFFFFFFFFFFFFF                                                                             [100%]
# ============================================= FAILURES =============================================
# ______________________________ test_proper_columns_queried[dataset0] _______________________________
#
# dataset =      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2   ...       111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]
#
#     @pytest.mark.parametrize("dataset", [
#         df,
#         df.head(5),
#         df.head(100),
#         df.head(0)
#     ])
#     def test_proper_columns_queried(dataset):
# ...

# %% [markdown]
# # Q6
# That's a lot of missing values? It's probably best to just drop this. How do I drop a column?

# %%
#workspace, scroll for solution
def drop_cabin_col(df):
  #YOUR CODE HERE
  """
  The Cabin column seems to have a lot of missing values. Drop this column and return the resulting dataframe
  """
  raise NotImplementedError("Need to implement drop_cabin_col() function")

# %%
# %%run_pytest
# @pytest.mark.parametrize("dataset", [
#     df,
#     df.head(5),
#     df.head(100),
#     df.head(0)
# ])
# def test_drop_cabin_col(dataset):
#   filtered = drop_cabin_col(dataset)
#   assert "Cabin" not in list(filtered.columns)
#   assert len(list(filtered.columns)) == len(list(dataset.columns)) - 1
#   assert filtered.shape[0] == dataset.shape[0]
# Out:
# %%run_pytest[clean] and %%run_pytest are deprecated in favor of %%ipytest. %%ipytest will clean tests, evaluate the cell and then run pytest. To disable cleaning, configure ipytest with ipytest.config(clean=False).
# FFFFFFFFFFFFFFFFFFFF                                                                         [100%]
# ============================================= FAILURES =============================================
# ______________________________ test_proper_columns_queried[dataset0] _______________________________
#
# dataset =      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2   ...       111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]
#
#     @pytest.mark.parametrize("dataset", [
#         df,
#         df.head(5),
#         df.head(100),
#         df.head(0)
#     ])
#     def test_proper_columns_queried(dataset):
# ...

# %% [markdown]
# # Q7
# I want to see the distribution of people that survived within each class.
#
#
# Heads up, this is a little more coding heavy. You'll need to put some thought in this!

# %%
#workspace, scroll for solution
def survived_within_class(df):
  #YOUR CODE HERE
  """
  For each Pclass, return the proportion of people who survived. Round answer to nearest 3 decimal places

  Return tuple in the format (Pclass 1 survival proportion, Pclass 2 survival proportion, Pclass 3 survival proportion)

  If there is a ZeroDivisionError, return (-1,-1,-1)
  """
  raise NotImplementedError("Need to implement survived_within_class()")

# %%
# %%run_pytest
# @pytest.mark.parametrize("dataset, expected", [
#     (df, (0.630, 0.473, 0.242)),
#     (df.head(100), (0.476, 0.667, 0.311)),
#     (df.head(5), (-1,-1,-1)),
#     (df.head(0), (-1,-1,-1))
# ])
# def test_survived_within_class(dataset, expected):
#   assert survived_within_class(dataset)[0] == expected[0]
#   assert survived_within_class(dataset)[1] == expected[1]
#   assert survived_within_class(dataset)[2] == expected[2]
# Out:
# %%run_pytest[clean] and %%run_pytest are deprecated in favor of %%ipytest. %%ipytest will clean tests, evaluate the cell and then run pytest. To disable cleaning, configure ipytest with ipytest.config(clean=False).
# FFFFFFFFFFFFFFFFFFFFFFFF                                                                     [100%]
# ============================================= FAILURES =============================================
# ______________________________ test_proper_columns_queried[dataset0] _______________________________
#
# dataset =      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2   ...       111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]
#
#     @pytest.mark.parametrize("dataset", [
#         df,
#         df.head(5),
#         df.head(100),
#         df.head(0)
#     ])
#     def test_proper_columns_queried(dataset):
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=282550a0-b371-4e1f-894f-81176ab33d44' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
